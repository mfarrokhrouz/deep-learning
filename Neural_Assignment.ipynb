# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(["EIN","NAME"],axis=1)

# %%
# Determine the number of unique values in each column.
application_cat = application_df.columns
application_df[application_cat].nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning

application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T17','T15','T29','T14','T25','T2','T12']

### The cutoff value in this calculation is 50 datapoints


application_types_to_replace
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# Other       54
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_list = pd.DataFrame(application_df["CLASSIFICATION"].value_counts())
class_list.head(-5)
# Out:
#        CLASSIFICATION
# C1000           17326
# C2000            6074
# C1200            4837
# C3000            1918
# C2100            1883
# ...               ...
# C1283               1
# C2380               1
# C1732               1
# C1728               1
# C2170               1
#
# [66 rows x 1 columns]

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
new_class_list = pd.DataFrame(class_list.CLASSIFICATION.loc[class_list.CLASSIFICATION > 1])
new_class_list
# Out:
#        CLASSIFICATION
# C1000           17326
# C2000            6074
# C1200            4837
# C3000            1918
# C2100            1883
# C7000             777
# C1700             287
# C4000             194
# C5000             116
# C1270             114
# C2700             104
# C2800              95
# C7100              75
# C1300              58
# C1280              50
# C1230              36
# C1400              34
# C7200              32
# C2300              32
# C1240              30
# C8000              20
# C7120              18
# C1500              16
# C1800              15
# C6000              15
# C1250              14
# C8200              11
# C1238              10
# C1278              10
# C1235               9
# C1237               9
# C7210               7
# C2400               6
# C1720               6
# C4100               6
# C1257               5
# C1600               5
# C1260               3
# C2710               3
# C0                  3
# ...

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

classifications_to_keep = ['C1000','C2000', 'C1200', 'C3000', 'C2100', 'C7000']
classifications_to_replace = []
# Replace in dataframe
for index,row in class_list.iterrows():
    if index not in classifications_to_keep:
        classifications_to_replace.append(index)

for cls in classifications_to_replace:        
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numerid_df = pd.get_dummies(application_df)
numerid_df.head(-5)
# Out:
#        STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1     5000              1                       0
# 1           1   108590              1                       0
# 2           1     5000              0                       0
# 3           1     6692              1                       0
# 4           1   142590              1                       0
# ...       ...      ...            ...                     ...
# 34289       1    20197              1                       0
# 34290       1     5000              0                       0
# 34291       1     5000              0                       0
# 34292       1     5000              0                       0
# 34293       1     5000              1                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T13  APPLICATION_TYPE_T19  \
# 0                         1                     0                     0
# 1                         0                     0                     0
# ...

# %%
# Split our preprocessed data into our features and target arrays

X = numerid_df.drop('IS_SUCCESSFUL', axis =1)
y = numerid_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=45, activation="relu", input_dim=46))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=45, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 45)                2115
#
#  dense_7 (Dense)             (None, 45)                2070
#
#  dense_8 (Dense)             (None, 1)                 46
#
# ...
# Total params: 4,231
# Trainable params: 4,231
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5565 - accuracy: 0.7285
# Epoch 2/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5544 - accuracy: 0.7304
# Epoch 3/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5511 - accuracy: 0.7313
# Epoch 4/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5511 - accuracy: 0.7317
# Epoch 5/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5491 - accuracy: 0.7327
# Epoch 6/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5484 - accuracy: 0.7335
# Epoch 7/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5475 - accuracy: 0.7318
# Epoch 8/50
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5461 - accuracy: 0.7336
# Epoch 9/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5461 - accuracy: 0.7322
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5526 - accuracy: 0.7259 - 721ms/epoch - 3ms/step
# Loss: 0.5525617003440857, Accuracy: 0.7259474992752075

# %%
# Export our model to HDF5 file
import numpy as np
import h5py
nn.save("result.h5")
